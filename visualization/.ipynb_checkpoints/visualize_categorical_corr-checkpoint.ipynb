# %% [markdown]
# # Load Items

# %%
import sys

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import scipy.stats as ss
import numpy as np
import pandas as pd
from collections import Counter
import math

sys.path.insert(0, '../preprocess')

import condense_csv

pd.set_option('display.max_columns', 100)
sns.set(color_codes=True)

# %%
train_X = pd.read_csv('../data/train.csv')
train_y = pd.read_csv('../data/train_labels.csv')  
train_X = condense_csv.compress_X(train_X)
train_y = condense_csv.compress_labels(train_y)
# Out:
# memory used before preprocess:  19.00808
#
# date time size before: 3.9798799999999996
# date time size after:  0.47528
#
# converting funder                         size:  3.86	->	 0.33
# converting installer                      size:  3.64	->	 0.34
# converting basin                          size:  4.03	->	 0.06
# converting subvillage                     size:  3.85	->	 2.03
# converting region                         size:  3.78	->	 0.06
# converting lga                            size:  3.83	->	 0.07
# converting ward                           size:  3.83	->	 0.34
# converting public_meeting                 size:  2.1	->	 0.06
# converting recorded_by                    size:  4.75	->	 0.06
# converting scheme_management              size:  3.55	->	 0.06
# converting scheme_name                    size:  3.15	->	 0.4
# converting permit                         size:  2.06	->	 0.06
# converting extraction_type                size:  3.84	->	 0.06
# converting extraction_type_group          size:  3.85	->	 0.06
# converting extraction_type_class          size:  3.84	->	 0.06
# converting management                     size:  3.64	->	 0.06
# converting management_group               size:  3.97	->	 0.06
# converting payment                        size:  4.02	->	 0.06
# converting payment_type                   size:  3.89	->	 0.06
# converting water_quality                  size:  3.64	->	 0.06
# converting quality_group                  size:  3.64	->	 0.06
# converting quantity                       size:  3.82	->	 0.06
# converting quantity_group                 size:  3.82	->	 0.06
# converting source                         size:  3.92	->	 0.06
# converting source_type                    size:  3.94	->	 0.06
# converting source_class                   size:  3.98	->	 0.06
# converting waterpoint_type                size:  4.27	->	 0.06
# converting waterpoint_type_group          size:  4.21	->	 0.06
#
# downcasting integers for: ['id', 'gps_height', 'num_private', 'region_code', 'district_code', 'population', 'construction_year']
#
# reduced memory usage for:   id                  from     0.48 to     0.24
# reduced memory usage for:   gps_height          from     0.48 to     0.12
# reduced memory usage for:   num_private         from     0.48 to     0.12
# reduced memory usage for:   region_code         from     0.48 to     0.06
# reduced memory usage for:   district_code       from     0.48 to     0.06
# reduced memory usage for:   population          from     0.48 to     0.12
# reduced memory usage for:   construction_year   from     0.48 to     0.12
#
# available RAM: svmem(total=8589934592, available=2546614272, percent=70.4, used=7353380864, free=456142848, active=3143106560, inactive=2090471424, wired=2119802880)
# available RAM: svmem(total=8589934592, available=2544619520, percent=70.4, used=7355486208, free=454148096, active=3143106560, inactive=2090471424, wired=2121908224)
#
# memory used after preprocess:  6.3896

# %%
train_X.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# 0               Lake Nyasa    Mnyusi B   Iringa           11              5
# 1            Lake Victoria     Nyamara     Mara           20              2
# 2                  Pangani     Majengo  Manyara           21              4
# 3  Ruvuma / Southern Coast  Mahakamani   Mtwara           90             63
# 4            Lake Victoria  Kyanyamisa   Kagera           18              1
#
#          lga        ward  population public_meeting              recorded_by  \
# 0     Ludewa    Mundindi         109           True  GeoData Consultants Ltd
# 1  Serengeti       Natta         280            NaN  GeoData Consultants Ltd
# 2  Simanjiro     Ngorika         250           True  GeoData Consultants Ltd
# 3   Nanyumbu    Nanyumbu          58           True  GeoData Consultants Ltd
# 4    Karagwe  Nyakasimbi           0           True  GeoData Consultants Ltd
#
#   scheme_management                  scheme_name permit  construction_year  \
# 0               VWC                        Roman  False               1999
# 1             Other                          NaN   True               2010
# 2               VWC  Nyumba ya mungu pipe scheme   True               2009
# 3               VWC                          NaN   True               1986
# 4               NaN                          NaN   True                  0
#
#   extraction_type extraction_type_group extraction_type_class management  \
# 0         gravity               gravity               gravity        vwc
# 1         gravity               gravity               gravity        wug
# 2         gravity               gravity               gravity        vwc
# 3     submersible           submersible           submersible        vwc
# 4         gravity               gravity               gravity      other
#
#   management_group         payment payment_type water_quality quality_group  \
# 0       user-group    pay annually     annually          soft          good
# 1       user-group       never pay    never pay          soft          good
# 2       user-group  pay per bucket   per bucket          soft          good
# 3       user-group       never pay    never pay          soft          good
# 4            other       never pay    never pay          soft          good
#
#        quantity quantity_group                source           source_type  \
# 0        enough         enough                spring                spring
# 1  insufficient   insufficient  rainwater harvesting  rainwater harvesting
# 2        enough         enough                   dam                   dam
# 3           dry            dry           machine dbh              borehole
# 4      seasonal       seasonal  rainwater harvesting  rainwater harvesting
#
#   source_class              waterpoint_type waterpoint_type_group
# 0  groundwater           communal standpipe    communal standpipe
# 1      surface           communal standpipe    communal standpipe
# 2      surface  communal standpipe multiple    communal standpipe
# 3  groundwater  communal standpipe multiple    communal standpipe
# 4      surface           communal standpipe    communal standpipe

# %%
train_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 40 columns):
# id                       59400 non-null int32
# amount_tsh               59400 non-null float64
# date_recorded            59400 non-null datetime64[ns]
# funder                   55765 non-null category
# gps_height               59400 non-null int16
# installer                55745 non-null category
# longitude                59400 non-null float64
# latitude                 59400 non-null float64
# wpt_name                 59400 non-null object
# num_private              59400 non-null int16
# basin                    59400 non-null category
# subvillage               59029 non-null category
# region                   59400 non-null category
# region_code              59400 non-null int8
# district_code            59400 non-null int8
# lga                      59400 non-null category
# ward                     59400 non-null category
# population               59400 non-null int16
# public_meeting           56066 non-null category
# recorded_by              59400 non-null category
# scheme_management        55523 non-null category
# scheme_name              31234 non-null category
# permit                   56344 non-null category
# construction_year        59400 non-null int16
# extraction_type          59400 non-null category
# extraction_type_group    59400 non-null category
# extraction_type_class    59400 non-null category
# management               59400 non-null category
# management_group         59400 non-null category
# payment                  59400 non-null category
# payment_type             59400 non-null category
# water_quality            59400 non-null category
# quality_group            59400 non-null category
# quantity                 59400 non-null category
# quantity_group           59400 non-null category
# source                   59400 non-null category
# source_type              59400 non-null category
# source_class             59400 non-null category
# waterpoint_type          59400 non-null category
# waterpoint_type_group    59400 non-null category
# dtypes: category(28), datetime64[ns](1), float64(3), int16(4), int32(1), int8(2), object(1)
# memory usage: 6.1+ MB

# %%
train_y.head()
# Out:
#       id    status_group
# 0  69572      functional
# 1   8776      functional
# 2  34310      functional
# 3  67743  non functional
# 4  19728      functional

# %% [markdown]
# # Functions

# %%
def cramers_v(x, y):
    """
    For finding correlations between categorical data.
    Cramers V is symmetric, which decreases information shown.
    0 is no association, 1 is full association
    
    :source: https://github.com/shakedzy/dython/blob/master/dython/nominal.py
    """

    confusion_matrix = pd.crosstab(x, y)
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
    rcorr = r-((r-1)**2)/(n-1)
    kcorr = k-((k-1)**2)/(n-1)
    return np.sqrt(phi2corr/min((kcorr-1), (rcorr-1)))

def conditional_entropy(x, y):
    """
    Calculates the conditional entropy of x given y: S(x|y)
    Wikipedia: https://en.wikipedia.org/wiki/Conditional_entropy
    :param x: list / NumPy ndarray / Pandas Series
        A sequence of measurements
    :param y: list / NumPy ndarray / Pandas Series
        A sequence of measurements
    :return: float
    
    :source: https://github.com/shakedzy/dython/blob/master/dython/nominal.py
    """
    
    # entropy of x given y
    y_counter = Counter(y)
    xy_counter = Counter(list(zip(x,y)))
    total_occurrences = sum(y_counter.values())
    entropy = 0.0
    for xy in xy_counter.keys():
        p_xy = xy_counter[xy] / total_occurrences
        p_y = y_counter[xy[1]] / total_occurrences
        entropy += p_xy * math.log(p_y/p_xy)
    return entropy

def theils_u(x, y):
    """
    Aka uncertainty coefficient.
    Given value of x, calculate the possible states of y and their occurence.
    Assymetrical
    
    :source: https://github.com/shakedzy/dython/blob/master/dython/nominal.py
    """
    s_xy = conditional_entropy(x, y)
    x_counter = Counter(x)
    total_occurrences = sum(x_counter.values())
    p_x = list(map(lambda n: n/total_occurrences, x_counter.values()))
    s_x = ss.entropy(p_x)
    if s_x == 0:
        return 1
    else:
        return (s_x - s_xy) / s_x
    
def check_with_theils(cols):
    """
    Check if the low cramers v categories also have low theils
    
    :param cols: list of columns to check
    :type  cols: list
    """
    
    for col in cols:
        calc_theils = theils_u(train_X[col], train_y['status_group'])
        print (col, '\n', calc_theils)
        calc_theils = theils_u(train_y['status_group'], train_X[col])
        print (calc_theils)

# %%
# example:
cramers_v(train_X['source'], train_y['status_group'])
# Out:
# 0.14811059560973563

# %% [markdown]
# # Correlation With Labels

# %%
def get_cat_corr_with_label (dfx, dfy):
    """
    Create a heat map for categorical correlations using Cramers V.
    
    :param dfx: dataframe of inputs
    :type  dfx: pandas.core.frame.DataFrame
    :param dfy: dataframe of labels
    :type  dfy: pandas.core.frame.DataFrame
    """
    
    cat_cols = dfx.select_dtypes(
    include=['category', 'object']
    )
    
    #corrs = []
    corrs = {}
    for col in cat_cols.columns:
        try:
            corr = cramers_v(dfx[col].dropna(), dfy['status_group'])
        except ZeroDivisionError:
            corrs[col] = 0
        corrs[col] = corr

        print (col, corr)
    corrs = pd.DataFrame(corrs, index=[1])
    plt.figure(figsize=(20,2))
    sns.heatmap(corrs, annot=True)
        
        
get_cat_corr_with_label(train_X, train_y)
# Out:
# funder 0.3050947684337318
# installer 0.3059323504743069
# wpt_name 0.1603488902938354
# basin 0.12663403694701172
# subvillage 0.3736358899849216
# region 0.20005871506460768
# lga 0.30816998601489476
# ward 0.4299756307032066
# public_meeting 0.07317230208747103
# recorded_by 0.07317230208747103
# scheme_management 0.12959899993678992
# scheme_name 0.5097800170374672
# permit 0.034171206063606664
# extraction_type 0.24842745816693432
# extraction_type_group 0.24690148970779827
# extraction_type_class 0.24133876082175432
# management 0.13165596946454589
# management_group 0.0485185288205425
# payment 0.18243010577935334
# payment_type 0.18243010577935334
# water_quality 0.13803116928255116
# quality_group 0.13264363276938332
# quantity 0.3091362740452046
# quantity_group 0.3091362740452046
# source 0.14811059560973563
# source_type 0.12629334316907617
# source_class 0.07024985234472723
# waterpoint_type 0.25022829400607893
# waterpoint_type_group 0.22669079655239402

# %%
"""
Notes:
I would say less than 10% correlation would be too low
management_group
permit
public_meeting
recorded_by
source_class
"""
# Out:
# 0.14811059560973563

# %%
# check with theils u
cols = ['management_group', 'permit', 'public_meeting', 'source_class']
check_with_theils(cols)
# Yep they are pretty low
# Out:
# management_group
#  0.005102195721449368
# 0.0028375250699954986
# permit
#  0.0010817068807107498
# 0.0009610102576385113
# public_meeting
#  0.006464690843280476
# 0.003648613661343587
# source_class
#  0.008180221681519618
# 0.005158336018044293

# %% [markdown]
# # Correlations with inputs only

# %%
def get_cat_corr_with_label (dfx):
    """
    Create a heat map for categorical correlations using theils u.
    
    :param dfx: dataframe of inputs
    :type  dfx: pandas.core.frame.DataFrame
    """
    
    cat_cols = dfx.select_dtypes(
        include=['category', 'object']
    ).sort_index(axis=1)
    
    corrs = {}
    for col in cat_cols.columns:
        col_corr = []
        for col2 in cat_cols.columns:  
            try:
                corr = theils_u(dfx[col], dfx[col2])
            except ZeroDivisionError:
                corr = 0
            
            col_corr.append(corr)
        corrs[col] = col_corr
        
    corrs = pd.DataFrame(corrs, index=sorted (cat_cols.columns)).sort_index(axis=1)
    plt.figure(figsize=(20,20))
    sns.heatmap(corrs, annot=True)

# %%
# takes way too long, mainly because some categories have so many possibilities
get_cat_corr_with_label (train_X)

# %%
"""
We are looking for super high correlations among the inputs

basin: ward
extraction_type: extraction_type_group, 
extraction_type_class: extraction_type_group, extraction_type
lga: ward
management_group: management
payment: payment type
quality_group: water_quality
quality: quality_group
quantity_group: quantity
region: iga, ward
source_class: source_type, source
source_type: source
water_quality: quality_group
waterpoint_type_group: waterpoint_type
"""
# Out:
# funder
# installer
# funder
# installer
# {'funder': [1.0, 0.6916370335139274], 'installer': [0.7449867916314815, 1.0]}

# %%
# test each one to see if there's correlations within the list
x1 = ['funder', 'installer']
x2 = ['basin', 'subvillage', 'region', 'lga', 'ward']
x3 = ['extraction_type', 'extraction_type_group', 'extraction_type_class']
x4 = ['management', 'management_group']
x5 = ['payment', 'payment_type']
x6 = ['water_quality', 'quality_group', 'quantity', 'quantity_group']
x7 = ['source', 'source_type', 'source_class', 'waterpoint_type', 'waterpoint_type_group']

# %%
theils_u(train_X['funder'], train_X['installer'])
# Out:
# 0.6916370335139274

# %%
sorted (train_X.columns)
# Out:
# ['amount_tsh',
#  'basin',
#  'construction_year',
#  'date_recorded',
#  'district_code',
#  'extraction_type',
#  'extraction_type_class',
#  'extraction_type_group',
#  'funder',
#  'gps_height',
#  'id',
#  'installer',
#  'latitude',
#  'lga',
#  'longitude',
#  'management',
#  'management_group',
#  'num_private',
#  'payment',
#  'payment_type',
#  'permit',
#  'population',
#  'public_meeting',
#  'quality_group',
#  'quantity',
#  'quantity_group',
#  'recorded_by',
#  'region',
#  'region_code',
#  'scheme_management',
#  'scheme_name',
#  'source',
#  'source_class',
#  'source_type',
#  'subvillage',
#  'ward',
#  'water_quality',
#  'waterpoint_type',
#  'waterpoint_type_group',
#  'wpt_name']

# %%
train_X.sort_index(axis=1)
# Out:
#        amount_tsh                    basin  construction_year date_recorded  \
# 0          6000.0               Lake Nyasa               1999    2011-03-14
# 1             0.0            Lake Victoria               2010    2013-03-06
# 2            25.0                  Pangani               2009    2013-02-25
# 3             0.0  Ruvuma / Southern Coast               1986    2013-01-28
# 4             0.0            Lake Victoria                  0    2011-07-13
# 5            20.0                  Pangani               2009    2011-03-13
# 6             0.0                 Internal                  0    2012-10-01
# 7             0.0          Lake Tanganyika                  0    2012-10-09
# 8             0.0          Lake Tanganyika                  0    2012-11-03
# 9             0.0            Lake Victoria                  0    2011-08-03
# 10            0.0              Wami / Ruvu               2011    2011-02-20
# 11          200.0               Lake Nyasa               1987    2013-02-18
# 12            0.0                 Internal                  0    2012-10-14
# 13            0.0                  Pangani               2009    2013-03-15
# 14            0.0                 Internal                  0    2012-10-20
# 15            0.0          Lake Tanganyika               1991    2011-08-04
# 16          500.0                   Rufiji               1978    2011-07-04
# 17            0.0                   Rufiji               1978    2011-09-04
# 18            0.0            Lake Victoria               1999    2011-07-22
# 19          500.0               Lake Nyasa               1992    2011-02-22
# 20          200.0               Lake Nyasa               2008    2011-02-27
# 21            0.0            Lake Victoria                  0    2013-02-10
# 22            0.0                   Rufiji               1978    2011-10-04
# 23          500.0                  Pangani               2011    2013-11-03
# 24            0.0          Lake Tanganyika               2009    2013-01-21
# 25            0.0                  Pangani               1974    2013-02-25
# 26          500.0  Ruvuma / Southern Coast               2011    2013-01-16
# 27            0.0            Lake Victoria                  0    2011-07-11
# 28            0.0                  Pangani               2000    2013-03-05
# 29            0.0                  Pangani               2002    2013-03-16
# ...           ...                      ...                ...           ...
# 59370       200.0          Lake Tanganyika                  0    2013-01-29
# 59371         0.0            Lake Victoria                  0    2012-10-09
# 59372         0.0          Lake Tanganyika                  0    2012-10-31
# 59373      5000.0               Lake Rukwa               1988    2013-01-30
# 59374         0.0            Lake Victoria                  0    2012-10-29
# 59375     40000.0                  Pangani               2005    2011-08-03
# 59376         0.0                 Internal               1990    2013-02-03
# 59377         0.0                 Internal                  0    2012-10-23
# 59378       500.0                   Rufiji               2008    2011-03-21
# 59379         0.0            Lake Victoria                  0    2011-07-13
# 59380      6000.0               Lake Nyasa               1999    2011-03-14
# 59381         0.0                  Pangani               1992    2011-03-16
# 59382         6.0                  Pangani               2008    2013-08-03
# 59383         0.0  Ruvuma / Southern Coast               2008    2013-01-19
# 59384         0.0            Lake Victoria                  0    2011-07-10
# 59385       500.0            Lake Victoria               2011    2012-11-03
# 59386         0.0               Lake Rukwa               2009    2011-08-22
# 59387       100.0              Wami / Ruvu               2000    2013-03-12
# 59388         0.0          Lake Tanganyika               1995    2013-01-29
# 59389         0.0          Lake Tanganyika               2009    2011-08-06
# 59390         0.0          Lake Tanganyika               1991    2011-08-04
# 59391         0.0                  Pangani               1967    2013-08-03
# 59392         0.0               Lake Rukwa                  0    2011-04-15
# 59393         0.0                 Internal                  0    2012-10-27
# 59394       500.0              Wami / Ruvu               2007    2011-03-09
# 59395        10.0                  Pangani               1999    2013-05-03
# 59396      4700.0                   Rufiji               1996    2011-05-07
# 59397         0.0                   Rufiji                  0    2011-04-11
# 59398         0.0                   Rufiji                  0    2011-03-08
# 59399         0.0              Wami / Ruvu               2002    2011-03-23
#
#        district_code extraction_type extraction_type_class  \
# 0                  5         gravity               gravity
# 1                  2         gravity               gravity
# 2                  4         gravity               gravity
# 3                 63     submersible           submersible
# 4                  1         gravity               gravity
# 5                  8     submersible           submersible
# 6                  3          swn 80              handpump
# 7                  3     nira/tanira              handpump
# 8                  6   india mark ii              handpump
# 9                  1     nira/tanira              handpump
# 10                43     submersible           submersible
# 11                 5          swn 80              handpump
# 12                 2     nira/tanira              handpump
# 13                 7         gravity               gravity
# 14                 6     nira/tanira              handpump
# 15                 2          swn 80              handpump
# 16                 4         gravity               gravity
# 17                 4         gravity               gravity
# 18                 1           other                 other
# 19                 5         gravity               gravity
# 20                 4         gravity               gravity
# 21                 1          swn 80              handpump
# 22                 4         gravity               gravity
# 23                 3         gravity               gravity
# 24                 3         gravity               gravity
# 25                 4         gravity               gravity
# 26                23   india mark ii              handpump
# 27                 1     nira/tanira              handpump
# 28                 1         gravity               gravity
# 29                 7         gravity               gravity
# ...              ...             ...                   ...
# 59370              2           other                 other
# 59371              2     nira/tanira              handpump
# 59372              4           other                 other
# 59373              1   india mark ii              handpump
# 59374              1     nira/tanira              handpump
# 59375              4         gravity               gravity
# 59376              2           other                 other
# 59377              2         gravity               gravity
# 59378              4         gravity               gravity
# 59379              3         gravity               gravity
# 59380              5         gravity               gravity
# 59381              8         gravity               gravity
# 59382              4         gravity               gravity
# 59383             62     nira/tanira              handpump
# 59384             30         gravity               gravity
# 59385              4         afridev              handpump
# 59386              2   india mark ii              handpump
# 59387              2     submersible           submersible
# 59388              1         gravity               gravity
# 59389              3   india mark ii              handpump
# 59390              2          swn 80              handpump
# 59391              3         gravity               gravity
# 59392              1         gravity               gravity
# 59393              2         gravity               gravity
# 59394              6     submersible           submersible
# 59395              5         gravity               gravity
# 59396              4         gravity               gravity
# 59397              7          swn 80              handpump
# 59398              4     nira/tanira              handpump
# 59399              2     nira/tanira              handpump
#
#       extraction_type_group                    funder  gps_height     id  \
# 0                   gravity                     Roman        1390  69572
# 1                   gravity                   Grumeti        1399   8776
# 2                   gravity              Lottery Club         686  34310
# 3               submersible                    Unicef         263  67743
# 4                   gravity               Action In A           0  19728
# 5               submersible       Mkinga Distric Coun           0   9944
# 6                    swn 80                      Dwsp           0  19816
# 7               nira/tanira                     Rwssp           0  54551
# 8             india mark ii                  Wateraid           0  53934
# 9               nira/tanira               Isingiro Ho           0  46144
# 10              submersible                   Private          62  49056
# 11                   swn 80                    Danida        1062  50409
# 12              nira/tanira              World Vision           0  36957
# 13                  gravity   Lawatefuka Water Supply        1368  50495
# 14              nira/tanira                     Biore           0  53752
# 15                   swn 80                     Rudep        1645  61848
# 16                  gravity                    Unicef        1703  48451
# 17                  gravity                    Unicef        1656  58155
# 18                    other                    Hesawa        1162  34169
# 19                  gravity                    Danida        1763  18274
# 20                  gravity                       Twe        2216  48375
# 21                   swn 80                      Dwsp           0   6091
# 22                  gravity                    Unicef        1510  58500
# 23                  gravity                       Isf         672  37862
# 24                  gravity  African Development Bank        1645  51058
# 25                  gravity    Government Of Tanzania        1273  22308
# 26            india mark ii                    Sobodo         200  55012
# 27              nira/tanira                    Hesawa           0  20145
# 28                  gravity    Government Of Tanzania        1443  19685
# 29                  gravity   Lawatefuka Water Supply        1256  69124
# ...                     ...                       ...         ...    ...
# 59370                 other                       NaN        1154  14796
# 59371           nira/tanira               Netherlands           0  20387
# 59372                 other                       Tlc           0  29940
# 59373         india mark ii                     Rudep        1137  15233
# 59374           nira/tanira                     Rwssp           0  49651
# 59375               gravity    Government Of Tanzania          54  50998
# 59376                 other                       NaN        1581  34716
# 59377               gravity    Government Of Tanzania           0  43986
# 59378               gravity                        Rc        2101  38067
# 59379               gravity                        Do           0  58255
# 59380               gravity                     Roman        1439  30647
# 59381               gravity       Mkinga Distric Coun           0  67885
# 59382               gravity                 Ces(gmbh)        1383  47002
# 59383           nira/tanira                World Bank          11  44616
# 59384               gravity                   Concern           0  72148
# 59385               afridev                     Jaica        1327  34473
# 59386         india mark ii                       Adb        1786  34952
# 59387           submersible                         0          25  26640
# 59388               gravity                     Kidep        1414  72559
# 59389         india mark ii                        Co         783  30410
# 59390                swn 80                     Rudep        1715  13677
# 59391               gravity    Government Of Tanzania         540  44885
# 59392               gravity    Government Of Tanzania           0  40607
# 59393               gravity                   Private           0  48348
# 59394           submersible                World Bank         351  11164
# 59395               gravity           Germany Republi        1210  60739
# 59396               gravity               Cefa-njombe        1212  27263
# 59397                swn 80                       NaN           0  37057
# 59398           nira/tanira                     Malec           0  31282
# 59399           nira/tanira                World Bank         191  26348
#
#                   installer      latitude               lga  longitude  \
# 0                     Roman -9.856322e+00            Ludewa  34.938093
# 1                   GRUMETI -2.147466e+00         Serengeti  34.698766
# 2              World vision -3.821329e+00         Simanjiro  37.460664
# 3                    UNICEF -1.115530e+01          Nanyumbu  38.486161
# 4                   Artisan -1.825359e+00           Karagwe  31.130847
# 5                       DWE -4.765587e+00            Mkinga  39.172796
# 6                      DWSP -3.766365e+00   Shinyanga Rural  33.362410
# 7                       DWE -4.226198e+00            Kahama  32.620617
# 8                 Water Aid -5.146712e+00      Tabora Urban  32.711100
# 9                   Artisan -1.257051e+00           Karagwe  30.626991
# 10                  Private -7.034139e+00          Mkuranga  39.209518
# 11                   DANIDA -1.057417e+01          Namtumbo  35.770258
# 12             World vision -3.290194e+00             Maswa  33.798106
# 13     Lawatefuka water sup -3.181783e+00              Siha  37.092574
# 14                   WEDECO -3.629333e+00             Meatu  34.364073
# 15                      DWE -8.274962e+00  Sumbawanga Rural  31.444121
# 16                      DWE -9.106185e+00            Njombe  34.642439
# 17                      DWE -9.085515e+00            Njombe  34.569266
# 18                      DWE -1.947868e+00           Ukerewe  32.920154
# 19                    Danid -9.894412e+00            Ludewa  34.508967
# 20                      TWE -9.594990e+00            Njombe  34.473430
# 21                      DWE -2.000000e-08           Bariadi   0.000000
# 22                      DWE -8.980014e+00            Njombe  34.586901
# 23                      ISF -4.125595e+00              Same  37.940029
# 24                      DWE -4.495568e+00      Kigoma Rural  29.747066
# 25                      DWE -3.317536e+00       Moshi Rural  37.422751
# 26              Kilolo Star -9.942532e+00       Lindi Rural  39.370777
# 27                      DWE -1.735361e+00           Karagwe  31.104257
# 28         District council -3.263526e+00             Rombo  37.611126
# 29     Lawatefuka water sup -3.191989e+00              Siha  37.061688
# ...                     ...           ...               ...        ...
# 59370                   NaN -4.902633e+00            Kasulu  30.058731
# 59371                   DWE -3.040369e+00             Maswa  33.586406
# 59372                   TLC -5.052101e+00            Urambo  32.058548
# 59373                Distri -6.784358e+00            Mpanda  32.125024
# 59374                   DWE -2.000000e-08           Bariadi   0.000000
# 59375                   DWE -5.061494e+00             Tanga  39.046942
# 59376                   NaN -5.076258e+00     Singida Rural  34.821039
# 59377            Government -4.423594e+00            Igunga  33.437012
# 59378                  ACRA -9.358405e+00            Njombe  34.620387
# 59379                    DO -1.820226e+00            Muleba  31.613284
# 59380                 Roman -9.849198e+00            Ludewa  34.942101
# 59381                   DWE -4.880204e+00            Mkinga  38.835001
# 59382                   DWE -3.323599e+00       Moshi Rural  37.454759
# 59383            World bank -1.005750e+01       Lindi Urban  39.626009
# 59384               CONCERN -2.483710e+00             Ngara  30.667805
# 59385              JAICA CO -2.021854e+00             Bunda  33.951681
# 59386                   DWE -8.532013e+00  Sumbawanga Rural  31.738789
# 59387                     0 -6.957098e+00             Ilala  39.176480
# 59388                   DWE -3.593827e+00           Kibondo  30.692400
# 59389                   DWE -7.365418e+00             Nkasi  30.646486
# 59390                   DWE -8.258160e+00  Sumbawanga Rural  31.370848
# 59391            Government -4.272218e+00              Same  38.044070
# 59392            Government -8.520888e+00            Chunya  33.009440
# 59393               Private -4.287410e+00            Igunga  33.866852
# 59394              ML appro -6.124830e+00           Mvomero  37.634053
# 59395                   CES -3.253847e+00               Hai  37.169807
# 59396                  Cefa -9.070629e+00            Njombe  35.249991
# 59397                   NaN -8.750434e+00           Mbarali  34.017087
# 59398                  Musa -6.378573e+00          Chamwino  35.861315
# 59399                 World -6.747464e+00    Morogoro Rural  38.104048
#
#              management management_group  num_private                payment  \
# 0                   vwc       user-group            0           pay annually
# 1                   wug       user-group            0              never pay
# 2                   vwc       user-group            0         pay per bucket
# 3                   vwc       user-group            0              never pay
# 4                 other            other            0              never pay
# 5                   vwc       user-group            0         pay per bucket
# 6                   vwc       user-group            0              never pay
# 7                   wug       user-group            0                unknown
# 8                   vwc       user-group            0              never pay
# 9                   vwc       user-group            0              never pay
# 10     private operator       commercial            0              never pay
# 11                  wug       user-group            0  pay when scheme fails
# 12                  wug       user-group            0                  other
# 13          water board       user-group            0            pay monthly
# 14                  wug       user-group            0              never pay
# 15                  vwc       user-group            0              never pay
# 16                  wua       user-group            0            pay monthly
# 17                  wua       user-group            0  pay when scheme fails
# 18                  vwc       user-group            0              never pay
# 19                  vwc       user-group            0           pay annually
# 20                  vwc       user-group            0            pay monthly
# 21                  wug       user-group            0                unknown
# 22                  wua       user-group            0              never pay
# 23                  vwc       user-group            0            pay monthly
# 24                  vwc       user-group            0                unknown
# 25                  vwc       user-group            0                unknown
# 26                  vwc       user-group            0            pay monthly
# 27                  vwc       user-group            0              never pay
# 28              company       commercial            0            pay monthly
# 29          water board       user-group            0            pay monthly
# ...                 ...              ...          ...                    ...
# 59370           unknown          unknown            0            pay monthly
# 59371               wug       user-group            0              never pay
# 59372  private operator       commercial            0         pay per bucket
# 59373               vwc       user-group            0           pay annually
# 59374               wug       user-group            0                  other
# 59375               vwc       user-group            0            pay monthly
# 59376               vwc       user-group            0                unknown
# 59377               vwc       user-group            0              never pay
# 59378               wua       user-group            0            pay monthly
# 59379               vwc       user-group            0              never pay
# 59380               vwc       user-group            0           pay annually
# 59381               vwc       user-group            0              never pay
# 59382       water board       user-group            0         pay per bucket
# 59383               vwc       user-group            0                unknown
# 59384               vwc       user-group            0              never pay
# 59385               wug       user-group            0            pay monthly
# 59386               vwc       user-group            0              never pay
# 59387               wua       user-group            0         pay per bucket
# 59388               vwc       user-group            0                unknown
# 59389               vwc       user-group            0              never pay
# 59390               vwc       user-group            0              never pay
# 59391               vwc       user-group            0              never pay
# 59392               vwc       user-group            0              never pay
# 59393  private operator       commercial            0         pay per bucket
# 59394               vwc       user-group            0            pay monthly
# 59395       water board       user-group            0         pay per bucket
# 59396               vwc       user-group            0           pay annually
# 59397               vwc       user-group            0            pay monthly
# 59398               vwc       user-group            0              never pay
# 59399               vwc       user-group            0  pay when scheme fails
#
#       payment_type permit  population public_meeting quality_group  \
# 0         annually  False         109           True          good
# 1        never pay   True         280            NaN          good
# 2       per bucket   True         250           True          good
# 3        never pay   True          58           True          good
# 4        never pay   True           0           True          good
# 5       per bucket   True           1           True         salty
# 6        never pay   True           0           True          good
# 7          unknown   True           0           True         milky
# 8        never pay   True           0           True         salty
# 9        never pay   True           0           True          good
# 10       never pay  False         345           True         salty
# 11      on failure  False         250           True          good
# 12           other  False           0           True          good
# 13         monthly   True           1           True          good
# 14       never pay   True           0           True          good
# 15       never pay  False         200           True          good
# 16         monthly   True          35           True          good
# 17      on failure   True          50           True          good
# 18       never pay   True        1000            NaN         milky
# 19        annually   True           1           True          good
# 20         monthly  False           4           True          good
# 21         unknown  False           0            NaN       unknown
# 22       never pay   True         350           True          good
# 23         monthly   True         210           True          good
# 24         unknown   True         156          False          good
# 25         unknown   True         140           True          good
# 26         monthly  False         260          False          good
# 27       never pay   True           0           True          good
# 28         monthly   True           1           True          good
# 29         monthly   True           1           True          good
# ...            ...    ...         ...            ...           ...
# 59370      monthly  False           1           True       unknown
# 59371    never pay  False           0           True          good
# 59372   per bucket   True           0           True         salty
# 59373     annually   True          96           True          good
# 59374        other  False           0           True          good
# 59375      monthly   True         609           True          good
# 59376      unknown    NaN           1           True       unknown
# 59377    never pay  False           0           True          good
# 59378      monthly   True          36           True          good
# 59379    never pay   True           0           True          good
# 59380     annually  False          50           True          good
# 59381    never pay   True         360           True          good
# 59382   per bucket   True           1           True          good
# 59383      unknown   True         800           True          good
# 59384    never pay  False           0           True          good
# 59385      monthly   True         200           True         salty
# 59386    never pay  False        1000           True          good
# 59387   per bucket  False         100            NaN          good
# 59388      unknown   True         500           True          good
# 59389    never pay  False        1500          False          good
# 59390    never pay  False         150           True          good
# 59391    never pay   True         210           True          good
# 59392    never pay   True           0           True          good
# 59393   per bucket  False           0          False          good
# 59394      monthly   True          89           True          good
# 59395   per bucket   True         125           True          good
# 59396     annually   True          56           True          good
# 59397      monthly  False           0           True      fluoride
# 59398    never pay   True           0           True          good
# 59399   on failure   True         150           True         salty
#
#            quantity quantity_group              recorded_by         region  \
# 0            enough         enough  GeoData Consultants Ltd         Iringa
# 1      insufficient   insufficient  GeoData Consultants Ltd           Mara
# 2            enough         enough  GeoData Consultants Ltd        Manyara
# 3               dry            dry  GeoData Consultants Ltd         Mtwara
# 4          seasonal       seasonal  GeoData Consultants Ltd         Kagera
# 5            enough         enough  GeoData Consultants Ltd          Tanga
# 6            enough         enough  GeoData Consultants Ltd      Shinyanga
# 7            enough         enough  GeoData Consultants Ltd      Shinyanga
# 8          seasonal       seasonal  GeoData Consultants Ltd         Tabora
# 9            enough         enough  GeoData Consultants Ltd         Kagera
# 10           enough         enough  GeoData Consultants Ltd          Pwani
# 11     insufficient   insufficient  GeoData Consultants Ltd         Ruvuma
# 12           enough         enough  GeoData Consultants Ltd      Shinyanga
# 13           enough         enough  GeoData Consultants Ltd    Kilimanjaro
# 14           enough         enough  GeoData Consultants Ltd      Shinyanga
# 15           enough         enough  GeoData Consultants Ltd          Rukwa
# 16              dry            dry  GeoData Consultants Ltd         Iringa
# 17              dry            dry  GeoData Consultants Ltd         Iringa
# 18     insufficient   insufficient  GeoData Consultants Ltd         Mwanza
# 19           enough         enough  GeoData Consultants Ltd         Iringa
# 20           enough         enough  GeoData Consultants Ltd         Iringa
# 21          unknown        unknown  GeoData Consultants Ltd      Shinyanga
# 22           enough         enough  GeoData Consultants Ltd         Iringa
# 23           enough         enough  GeoData Consultants Ltd    Kilimanjaro
# 24           enough         enough  GeoData Consultants Ltd         Kigoma
# 25           enough         enough  GeoData Consultants Ltd    Kilimanjaro
# 26           enough         enough  GeoData Consultants Ltd          Lindi
# 27           enough         enough  GeoData Consultants Ltd         Kagera
# 28     insufficient   insufficient  GeoData Consultants Ltd    Kilimanjaro
# 29           enough         enough  GeoData Consultants Ltd    Kilimanjaro
# ...             ...            ...                      ...            ...
# 59370       unknown        unknown  GeoData Consultants Ltd         Kigoma
# 59371        enough         enough  GeoData Consultants Ltd      Shinyanga
# 59372  insufficient   insufficient  GeoData Consultants Ltd         Tabora
# 59373        enough         enough  GeoData Consultants Ltd          Rukwa
# 59374        enough         enough  GeoData Consultants Ltd      Shinyanga
# 59375        enough         enough  GeoData Consultants Ltd          Tanga
# 59376           dry            dry  GeoData Consultants Ltd        Singida
# 59377  insufficient   insufficient  GeoData Consultants Ltd         Tabora
# 59378        enough         enough  GeoData Consultants Ltd         Iringa
# 59379        enough         enough  GeoData Consultants Ltd         Kagera
# 59380           dry            dry  GeoData Consultants Ltd         Iringa
# 59381  insufficient   insufficient  GeoData Consultants Ltd          Tanga
# 59382        enough         enough  GeoData Consultants Ltd    Kilimanjaro
# 59383        enough         enough  GeoData Consultants Ltd          Lindi
# 59384  insufficient   insufficient  GeoData Consultants Ltd         Kagera
# 59385        enough         enough  GeoData Consultants Ltd           Mara
# 59386        enough         enough  GeoData Consultants Ltd          Rukwa
# 59387        enough         enough  GeoData Consultants Ltd  Dar es Salaam
# 59388  insufficient   insufficient  GeoData Consultants Ltd         Kigoma
# 59389        enough         enough  GeoData Consultants Ltd          Rukwa
# 59390  insufficient   insufficient  GeoData Consultants Ltd          Rukwa
# 59391        enough         enough  GeoData Consultants Ltd    Kilimanjaro
# 59392        enough         enough  GeoData Consultants Ltd          Mbeya
# 59393  insufficient   insufficient  GeoData Consultants Ltd         Tabora
# 59394        enough         enough  GeoData Consultants Ltd       Morogoro
# 59395        enough         enough  GeoData Consultants Ltd    Kilimanjaro
# 59396        enough         enough  GeoData Consultants Ltd         Iringa
# 59397        enough         enough  GeoData Consultants Ltd          Mbeya
# 59398  insufficient   insufficient  GeoData Consultants Ltd         Dodoma
# 59399        enough         enough  GeoData Consultants Ltd       Morogoro
#
#        region_code scheme_management                            scheme_name  \
# 0               11               VWC                                  Roman
# 1               20             Other                                    NaN
# 2               21               VWC            Nyumba ya mungu pipe scheme
# 3               90               VWC                                    NaN
# 4               18               NaN                                    NaN
# 5                4               VWC                              Zingibali
# 6               17               VWC                                    NaN
# 7               17               NaN                                    NaN
# 8               14               VWC                                    NaN
# 9               18               NaN                                    NaN
# 10              60  Private operator                                    NaN
# 11              10               WUG                                    NaN
# 12              17               WUG                                    NaN
# 13               3       Water Board                             BL Bondeni
# 14              17               WUG                                   None
# 15              15               VWC                                    NaN
# 16              11               WUA            wanging'ombe water supply s
# 17              11               WUA            wanging'ombe water supply s
# 18              19               NaN                                    NaN
# 19              11               VWC                                 Makanj
# 20              11               VWC                                 Kidabu
# 21              17               WUG                                    NaN
# 22              11               WUA            wanging'ombe water supply s
# 23               3   Water authority                              Mashangwi
# 24              16               VWC                     Quick wins Program
# 25               3               VWC                         Komaka mandaka
# 26              80               VWC                 Sobodo Borehole Scheme
# 27              18               NaN                                    NaN
# 28               3           Company                  Kitukuni water supply
# 29               3       Water Board                           BL Mwakikoti
# ...            ...               ...                                    ...
# 59370           16               NaN                                    NaN
# 59371           17               WUG                                    NaN
# 59372           14  Private operator                                    NaN
# 59373           15               VWC                                    NaN
# 59374           17               WUG                                    NaN
# 59375            4               VWC                   Mzizima Water Supply
# 59376           13               VWC                                    NaN
# 59377           14   Water authority                                    NaN
# 59378           11               VWC                           Tove mtwango
# 59379           18               VWC                                      N
# 59380           11               VWC                                  Roman
# 59381            4               VWC                     Magati water schem
# 59382            3       Water Board  Kirua kahe gravity water supply trust
# 59383           80               NaN                                    NaN
# 59384           18               VWC                                    NaN
# 59385           20               WUG                                    NaN
# 59386           15               VWC                                    NaN
# 59387            7               WUA                                      M
# 59388           16               VWC                                    NaN
# 59389           15               VWC                                    NaN
# 59390           15               VWC                                    NaN
# 59391            3   Water authority                              Hingilili
# 59392           12               VWC                                    NaN
# 59393           14   Water authority                                    NaN
# 59394            5               VWC                                    NaN
# 59395            3       Water Board                 Losaa Kia water supply
# 59396           11               VWC            Ikondo electrical water sch
# 59397           12               VWC                                    NaN
# 59398            1               VWC                                    NaN
# 59399            5               VWC                                    NaN
#
#                      source source_class           source_type  \
# 0                    spring  groundwater                spring
# 1      rainwater harvesting      surface  rainwater harvesting
# 2                       dam      surface                   dam
# 3               machine dbh  groundwater              borehole
# 4      rainwater harvesting      surface  rainwater harvesting
# 5                     other      unknown                 other
# 6               machine dbh  groundwater              borehole
# 7              shallow well  groundwater          shallow well
# 8               machine dbh  groundwater              borehole
# 9              shallow well  groundwater          shallow well
# 10              machine dbh  groundwater              borehole
# 11             shallow well  groundwater          shallow well
# 12             shallow well  groundwater          shallow well
# 13                   spring  groundwater                spring
# 14             shallow well  groundwater          shallow well
# 15              machine dbh  groundwater              borehole
# 16                    river      surface            river/lake
# 17                    river      surface            river/lake
# 18                   spring  groundwater                spring
# 19                   spring  groundwater                spring
# 20                   spring  groundwater                spring
# 21             shallow well  groundwater          shallow well
# 22                    river      surface            river/lake
# 23                    river      surface            river/lake
# 24                   spring  groundwater                spring
# 25                   spring  groundwater                spring
# 26              machine dbh  groundwater              borehole
# 27             shallow well  groundwater          shallow well
# 28                   spring  groundwater                spring
# 29                   spring  groundwater                spring
# ...                     ...          ...                   ...
# 59370               unknown      unknown                 other
# 59371          shallow well  groundwater          shallow well
# 59372          shallow well  groundwater          shallow well
# 59373           machine dbh  groundwater              borehole
# 59374          shallow well  groundwater          shallow well
# 59375                 river      surface            river/lake
# 59376          shallow well  groundwater          shallow well
# 59377                   dam      surface                   dam
# 59378                spring  groundwater                spring
# 59379                spring  groundwater                spring
# 59380                spring  groundwater                spring
# 59381                spring  groundwater                spring
# 59382                spring  groundwater                spring
# 59383  rainwater harvesting      surface  rainwater harvesting
# 59384                spring  groundwater                spring
# 59385           machine dbh  groundwater              borehole
# 59386           machine dbh  groundwater              borehole
# 59387           machine dbh  groundwater              borehole
# 59388                spring  groundwater                spring
# 59389           machine dbh  groundwater              borehole
# 59390           machine dbh  groundwater              borehole
# 59391                 river      surface            river/lake
# 59392                spring  groundwater                spring
# 59393                   dam      surface                   dam
# 59394           machine dbh  groundwater              borehole
# 59395                spring  groundwater                spring
# 59396                 river      surface            river/lake
# 59397           machine dbh  groundwater              borehole
# 59398          shallow well  groundwater          shallow well
# 59399          shallow well  groundwater          shallow well
#
#                subvillage                ward water_quality  \
# 0                Mnyusi B            Mundindi          soft
# 1                 Nyamara               Natta          soft
# 2                 Majengo             Ngorika          soft
# 3              Mahakamani            Nanyumbu          soft
# 4              Kyanyamisa          Nyakasimbi          soft
# 5             Moa/Mwereme                 Moa         salty
# 6           Ishinabulandi              Samuye          soft
# 7         Nyawishi Center              Chambo         milky
# 8              Imalauduki            Itetemia         salty
# 9                Mkonomre              Kaisho          soft
# 10                 Mizugo             Tambani         salty
# 11           Ngondombwito              Msindo          soft
# 12                Nkilifa            Busilili          soft
# 13                Omarini      Siha Kaskazini          soft
# 14              Mwabasabi               Nkoma          soft
# 15                  Tunzi               Mkowe          soft
# 16               Kidudumo              Mdandu          soft
# 17                 Yeriko               Usuka          soft
# 18                 Center            Ilangala         milky
# 19               Manyanya             Mawengi          soft
# 20                Majengo              Matola          soft
# 21             Ibabachegu   Ikungulyabashashi       unknown
# 22              Mkanivega               Usuka          soft
# 23             Mkonga Juu            Kisiwani          soft
# 24                  Msasa               Mkigo          soft
# 25               Kitereni             Kimochi          soft
# 26                Shuleni             Rutamba          soft
# 27              Chakahaya           Nyaishozi          soft
# 28                  Kiyao        Mengwe Manda          soft
# 29                 Merali           Siha Kati          soft
# ...                   ...                 ...           ...
# 59370            Mazungwe              Rusesa       unknown
# 59371             Chambwa              Kulimi          soft
# 59372    Urambo Magharibi              Urambo         salty
# 59373           Mapambano               Ilela          soft
# 59374          Mwamtani A              Sagata          soft
# 59375          Kwa Nyanji             Mzizima          soft
# 59376                  Hu           Dung'unyi       unknown
# 59377            Hospital              Nkinga          soft
# 59378            Igelango            Imalinyi          soft
# 59379           Kaluyango              Ikondo          soft
# 59380            Mnyusi B            Mundindi          soft
# 59381           Mtakuja A             Maramba          soft
# 59382            Yamu Juu  Kirua Vunjo Kusini          soft
# 59383           Mitumbati             Jamhuri          soft
# 59384          Songambele           Nyamiyaga          soft
# 59385             Mlimani              Mcharo         salty
# 59386               Nduza              Katazi          soft
# 59387  Mtaa Wa Yangeyange            Msongola          soft
# 59388            Kumwambu       Kibondo Urban          soft
# 59389             Itete B             Kirando          soft
# 59390             Kitonto               Mkowe          soft
# 59391          Maore Kati               Maore          soft
# 59392           Mbuyuni A             Mbuyuni          soft
# 59393             Masanga              Igunga          soft
# 59394            Komstari            Diongoya          soft
# 59395            Kiduruni    Masama Magharibi          soft
# 59396            Igumbilo              Ikondo          soft
# 59397           Madungulu             Chimala      fluoride
# 59398              Mwinyi        Mvumi Makulu          soft
# 59399        Kikatanyemba          Ngerengere         salty
#
#                    waterpoint_type waterpoint_type_group  \
# 0               communal standpipe    communal standpipe
# 1               communal standpipe    communal standpipe
# 2      communal standpipe multiple    communal standpipe
# 3      communal standpipe multiple    communal standpipe
# 4               communal standpipe    communal standpipe
# 5      communal standpipe multiple    communal standpipe
# 6                        hand pump             hand pump
# 7                        hand pump             hand pump
# 8                        hand pump             hand pump
# 9                        hand pump             hand pump
# 10                           other                 other
# 11                       hand pump             hand pump
# 12                       hand pump             hand pump
# 13              communal standpipe    communal standpipe
# 14                       hand pump             hand pump
# 15                       hand pump             hand pump
# 16              communal standpipe    communal standpipe
# 17              communal standpipe    communal standpipe
# 18                           other                 other
# 19              communal standpipe    communal standpipe
# 20              communal standpipe    communal standpipe
# 21                       hand pump             hand pump
# 22              communal standpipe    communal standpipe
# 23              communal standpipe    communal standpipe
# 24                 improved spring       improved spring
# 25              communal standpipe    communal standpipe
# 26                       hand pump             hand pump
# 27                       hand pump             hand pump
# 28              communal standpipe    communal standpipe
# 29              communal standpipe    communal standpipe
# ...                            ...                   ...
# 59370                        other                 other
# 59371                    hand pump             hand pump
# 59372                        other                 other
# 59373                    hand pump             hand pump
# 59374                    hand pump             hand pump
# 59375           communal standpipe    communal standpipe
# 59376                        other                 other
# 59377  communal standpipe multiple    communal standpipe
# 59378           communal standpipe    communal standpipe
# 59379           communal standpipe    communal standpipe
# 59380           communal standpipe    communal standpipe
# 59381           communal standpipe    communal standpipe
# 59382           communal standpipe    communal standpipe
# 59383                    hand pump             hand pump
# 59384           communal standpipe    communal standpipe
# 59385                    hand pump             hand pump
# 59386                    hand pump             hand pump
# 59387           communal standpipe    communal standpipe
# 59388              improved spring       improved spring
# 59389                    hand pump             hand pump
# 59390                    hand pump             hand pump
# 59391           communal standpipe    communal standpipe
# 59392           communal standpipe    communal standpipe
# 59393                        other                 other
# 59394           communal standpipe    communal standpipe
# 59395           communal standpipe    communal standpipe
# 59396           communal standpipe    communal standpipe
# 59397                    hand pump             hand pump
# 59398                    hand pump             hand pump
# 59399                    hand pump             hand pump
#
#                         wpt_name
# 0                           none
# 1                       Zahanati
# 2                    Kwa Mahundi
# 3           Zahanati Ya Nanyumbu
# 4                        Shuleni
# 5                         Tajiri
# 6                     Kwa Ngomho
# 7                   Tushirikiane
# 8              Kwa Ramadhan Musa
# 9                        Kwapeto
# 10                 Mzee Hokororo
# 11              Kwa Alid Nchimbi
# 12                         Pamba
# 13          Kwa John Izack Mmari
# 14                     Mwabasabi
# 15        Kwa Juvenal Ching'Ombe
# 16               Kwa John Mtenzi
# 17               Kwa Rose Chaula
# 18                        Ngomee
# 19                          none
# 20                          none
# 21                      Muungano
# 22                       Shuleni
# 23                       Kinonga
# 24                       Kamsasa
# 25                     Kwa Tukai
# 26         Ruhoma Primary School
# 27                    Kwawilliam
# 28                  Kwa Kibakaya
# 29             Kwa Willium Kinda
# ...                          ...
# 59370             Village Office
# 59371                   Ushirika
# 59372           Kwa Mzee Kamanya
# 59373                Kwa Kadiega
# 59374                 Nguvu Kazi
# 59375                  Sekondari
# 59376                    Nasingo
# 59377                       Fpct
# 59378             Michael Msigwa
# 59379            Coffee Plantati
# 59380                       none
# 59381                 Mijohoroni
# 59382             Kwa Luka Msaki
# 59383                    Shuleni
# 59384                   Chamkube
# 59385                Kwa Marunda
# 59386  Shule Ya Sekondari Katazi
# 59387                 Kwa Maliba
# 59388         Kwa Philipo Kibeba
# 59389                  Sekondari
# 59390            Kwa Mzee Atanas
# 59391                        Kwa
# 59392             Benard Charles
# 59393                  Kwa Peter
# 59394                 Chimeredya
# 59395        Area Three Namba 27
# 59396          Kwa Yahona Kuvala
# 59397                    Mashine
# 59398                     Mshoro
# 59399            Kwa Mzee Lugawa
#
# [59400 rows x 40 columns]
