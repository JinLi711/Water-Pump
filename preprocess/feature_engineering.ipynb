# %% [markdown]
# # Load Items

# %%
import json
import pandas as pd
import numpy as np
import condense_csv
import pprint
import scipy.stats as ss

# %%
train_X = pd.read_csv('../data/train.csv')
train_y = pd.read_csv('../data/train_labels.csv')  
train_X = condense_csv.compress_X(train_X)
train_y = condense_csv.compress_labels(train_y)
# Out:
# memory used before preprocess:  19.00808
#
# date time size before: 3.9798799999999996
# date time size after:  0.47528
#
# converting funder                         size:  3.86	->	 0.33
# converting installer                      size:  3.64	->	 0.34
# converting basin                          size:  4.03	->	 0.06
# converting subvillage                     size:  3.85	->	 2.03
# converting region                         size:  3.78	->	 0.06
# converting lga                            size:  3.83	->	 0.07
# converting ward                           size:  3.83	->	 0.34
# converting public_meeting                 size:  2.1	->	 0.06
# converting recorded_by                    size:  4.75	->	 0.06
# converting scheme_management              size:  3.55	->	 0.06
# converting scheme_name                    size:  3.15	->	 0.4
# converting permit                         size:  2.06	->	 0.06
# converting extraction_type                size:  3.84	->	 0.06
# converting extraction_type_group          size:  3.85	->	 0.06
# converting extraction_type_class          size:  3.84	->	 0.06
# converting management                     size:  3.64	->	 0.06
# converting management_group               size:  3.97	->	 0.06
# converting payment                        size:  4.02	->	 0.06
# converting payment_type                   size:  3.89	->	 0.06
# converting water_quality                  size:  3.64	->	 0.06
# converting quality_group                  size:  3.64	->	 0.06
# converting quantity                       size:  3.82	->	 0.06
# converting quantity_group                 size:  3.82	->	 0.06
# converting source                         size:  3.92	->	 0.06
# converting source_type                    size:  3.94	->	 0.06
# converting source_class                   size:  3.98	->	 0.06
# converting waterpoint_type                size:  4.27	->	 0.06
# converting waterpoint_type_group          size:  4.21	->	 0.06
#
# downcasting integers for: ['id', 'gps_height', 'num_private', 'region_code', 'district_code', 'population', 'construction_year']
#
# reduced memory usage for:   id                  from     0.48 to     0.24
# reduced memory usage for:   gps_height          from     0.48 to     0.12
# reduced memory usage for:   num_private         from     0.48 to     0.12
# reduced memory usage for:   region_code         from     0.48 to     0.06
# reduced memory usage for:   district_code       from     0.48 to     0.06
# reduced memory usage for:   population          from     0.48 to     0.12
# reduced memory usage for:   construction_year   from     0.48 to     0.12
#
# available RAM: svmem(total=8589934592, available=2264678400, percent=73.6, used=6785912832, free=272793600, active=2688450560, inactive=1991884800, wired=2105577472)
# available RAM: svmem(total=8589934592, available=2261917696, percent=73.7, used=6789967872, free=270032896, active=2688483328, inactive=1991884800, wired=2109599744)
#
# memory used after preprocess:  6.3896

# %%
train_X.info()#.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 40 columns):
# id                       59400 non-null int32
# amount_tsh               59400 non-null float64
# date_recorded            59400 non-null datetime64[ns]
# funder                   55765 non-null category
# gps_height               59400 non-null int16
# installer                55745 non-null category
# longitude                59400 non-null float64
# latitude                 59400 non-null float64
# wpt_name                 59400 non-null object
# num_private              59400 non-null int16
# basin                    59400 non-null category
# subvillage               59029 non-null category
# region                   59400 non-null category
# region_code              59400 non-null int8
# district_code            59400 non-null int8
# lga                      59400 non-null category
# ward                     59400 non-null category
# population               59400 non-null int16
# public_meeting           56066 non-null category
# recorded_by              59400 non-null category
# scheme_management        55523 non-null category
# scheme_name              31234 non-null category
# permit                   56344 non-null category
# construction_year        59400 non-null int16
# extraction_type          59400 non-null category
# extraction_type_group    59400 non-null category
# extraction_type_class    59400 non-null category
# management               59400 non-null category
# management_group         59400 non-null category
# payment                  59400 non-null category
# payment_type             59400 non-null category
# water_quality            59400 non-null category
# quality_group            59400 non-null category
# quantity                 59400 non-null category
# quantity_group           59400 non-null category
# source                   59400 non-null category
# source_type              59400 non-null category
# source_class             59400 non-null category
# waterpoint_type          59400 non-null category
# waterpoint_type_group    59400 non-null category
# dtypes: category(28), datetime64[ns](1), float64(3), int16(4), int32(1), int8(2), object(1)
# memory usage: 6.1+ MB

# %%
# dictz = {
#     'a': [1, 2, 'b'],
#     'd': [5, 6, 11]
# }

# with open('test.json', 'w') as outfile:
#     json.dump (dictz, outfile)
    
# The initial conditions of the class
file = open('starting_info.json')
starting_info = json.load(file)
file.close()
starting_info
#pd.DataFrame(starting_info)
# Out:
# {'amount_tsh': [['binning_5'], 'Large outliers. Can also try log or box cox'],
#  'date_recorded': [['finddays'], 'Need to convert to days.'],
#  'funder': [['cbinning_50'], '1900 categories'],
#  'id': [['drop'], 'All IDs are unique.']}

# %%
class ColumnOperations:
    """
    A class for representing column operations to be performed for the dataframe
    """
    
    def __init__(self, name, operations, justifications):
        """
        :param name: column name
        :type  name: str
        :param operations: a sequence of operations to be performed on the column
        :type  operations: list
        :param justification: justification for operation
        :type  justification: str
        """
        
        self.name = name
        self.operations = operations
        self.justifications = justifications

# %%
def create_col_instances(col_dict):
    """
    Create a list of instances of the column operation class
    
    :param col_dict: dictionary where keys are column names and values are the class attributes
    :type  col_dict: dict
    :returns: list of class instances
    :rtype:   list
    """
    
    col_instances = []
    for col_name, attributes in col_dict.items():
        col_instances.append(ColumnOperations(col_name, attributes[0], attributes[1]))
    return col_instances
        
list_of_classes = create_col_instances(starting_info)
pprint.pprint (list_of_classes)
# Out:
# [<__main__.ColumnOperations object at 0x1a1925b5f8>,
#  <__main__.ColumnOperations object at 0x1a1925b550>,
#  <__main__.ColumnOperations object at 0x1a1925b4e0>,
#  <__main__.ColumnOperations object at 0x1a1925b4a8>]

# %%
#x[0].justifications

def perform_operations(df, col_name, operations):
    """
    Execute operations on a certain column in the dataframe.
        Operations:      Description:
        drop             drop the entire column
        log              perform log transformation on the column
        box cox          perform box cox transformation on the column
        binning_NUM      create NUM amount of bins
        outlierZ_NUM     remove outliers with z score > NUM
        drop0            drop all values with zeros in it
        median0          replace 0 with the median
        finddays         convert datetime to days since the first day
        cbinning_NUM     create bins where each bin must have occurences of NUM or higher
    
    :param df: dataframe 
    :type  df: pandas.core.frame.DataFrame
    :param col_name: name of column
    :type  col_name: str
    :param operations: list of operations to perform on the certain column
    :type  operations: list
    :returns: transformed dataframe 
    :rtype:   pandas.core.frame.DataFrame
    """
    
    col = df[col_name]
    
    for operation in operations:
        if operation == 'drop':
            return df.drop(col_name, axis=1)
        
        elif str (col.dtype) in {'int8', 'int16', 'int32', 'float64'}:
            if operation == 'log':
                col = np.log(1 + col) # to make sure no divide by zero
            elif operation == 'box cox':
                col = ss.boxcox(col + 0.001) # to make sure no divide by zero
            elif operation == "drop0":
                df = df[col != 0]
                col = col[col != 0]
            elif operation == "median0":
                from sklearn.preprocessing import Imputer
                col[col == 0] = np.nan
                imputer = Imputer(strategy="median")
                col = imputer.fit_transform(col.values.reshape(-1, 1))
                #print (col)
            elif operation.split('_')[0] == 'binning':
                num = int (operation.split('_')[1])
                quantile_list = [i  / (num - 1) for i in range (num )]
                print (quantile_list)
                col = pd.qcut(
                    col, 
                    q=quantile_list,
                    duplicates='drop'
                )
            elif operation.split('_')[0] == 'outlierZ':
                z = np.abs(ss.zscore(col))
                keep_values = z < float (operation.split('_')[1])
                df = df[keep_values]
                col = col[keep_values]
            else:
                raise ValueError('Not an available operation')
        
        elif str(col.dtype) in {'datetime64[ns]'}:
            if operation == "finddays":
                col = (col - min(col)).dt.days
        elif str (col.dtype) in {'category', 'object'}:
            #print ('Did not do this yet', col)
            if operation.split('_')[0] == "cbinning":
                num = float (operation.split('_')[1])
                value_counts = col.value_counts()
                x = col.replace(value_counts)
                df[col_name][df[col_name] == '0'] = np.nan
                df[col_name] = df[col_name].cat.add_categories(['OTHER'])
                df[col_name] = df[col_name].fillna('OTHER')
                df.loc[x < num, col_name] = 'OTHER'
                return df
                
        else:
            raise ValueError('Not an available data type')
    
    df[col_name] = col 
    
    return df

# %%
def perform_operations_with_classes(df, list_of_classes):
    for col_class in list_of_classes:
        df = perform_operations(df, col_class.name, col_class.operations)
    return df
    
#perform_operations_with_classes(train_X, list_of_classes)

# %%
#perform_operations(train_X, 'id', ['drop']).head()
#perform_operations(train_X, 'amount_tsh', ['binning_6']).head()
#perform_operations(train_X, 'amount_tsh', ['outlierZ_3'])#.head()
#perform_operations(train_X, 'amount_tsh', ['median0'])#.head()
#perform_operations(train_X, 'funder', ['cbinning_50'])#.head()

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class DataCleaning(BaseEstimator, TransformerMixin):
    """
    Class for performing data cleaning, so the same can be applied to the test case
    """
    
    def __init__(self, class_list=list_of_classes):
        self.class_list = class_list
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None):
        X_transformed = perform_operations_with_classes(X, self.class_list)
        return X_transformed

# %%
trans = DataCleaning()
xxx = trans.transform(train_X)
# Out:
# [0.0, 0.25, 0.5, 0.75, 1.0]

# %%
xxx#.head()
# Out:
#              amount_tsh  date_recorded                   funder  gps_height  \
# 0      (20.0, 350000.0]           3073                    Roman        1390
# 1        (-0.001, 20.0]           3796                  Grumeti        1399
# 2      (20.0, 350000.0]           3787                    OTHER         686
# 3        (-0.001, 20.0]           3759                   Unicef         263
# 4        (-0.001, 20.0]           3194                    OTHER           0
# 5        (-0.001, 20.0]           3072      Mkinga Distric Coun           0
# 6        (-0.001, 20.0]           3640                     Dwsp           0
# 7        (-0.001, 20.0]           3648                    Rwssp           0
# 8        (-0.001, 20.0]           3673                 Wateraid           0
# 9        (-0.001, 20.0]           3215                    OTHER           0
# 10       (-0.001, 20.0]           3051                  Private          62
# 11     (20.0, 350000.0]           3780                   Danida        1062
# 12       (-0.001, 20.0]           3653             World Vision           0
# 13       (-0.001, 20.0]           3805  Lawatefuka Water Supply        1368
# 14       (-0.001, 20.0]           3659                    OTHER           0
# 15       (-0.001, 20.0]           3216                    Rudep        1645
# 16     (20.0, 350000.0]           3185                   Unicef        1703
# 17       (-0.001, 20.0]           3247                   Unicef        1656
# 18       (-0.001, 20.0]           3203                   Hesawa        1162
# 19     (20.0, 350000.0]           3053                   Danida        1763
# 20     (20.0, 350000.0]           3058                      Twe        2216
# 21       (-0.001, 20.0]           3772                     Dwsp           0
# 22       (-0.001, 20.0]           3277                   Unicef        1510
# 23     (20.0, 350000.0]           4038                      Isf         672
# 24       (-0.001, 20.0]           3752                    OTHER        1645
# 25       (-0.001, 20.0]           3787   Government Of Tanzania        1273
# 26     (20.0, 350000.0]           3747                    OTHER         200
# 27       (-0.001, 20.0]           3192                   Hesawa           0
# 28       (-0.001, 20.0]           3795   Government Of Tanzania        1443
# 29       (-0.001, 20.0]           3806  Lawatefuka Water Supply        1256
# ...                 ...            ...                      ...         ...
# 59370  (20.0, 350000.0]           3760                    OTHER        1154
# 59371    (-0.001, 20.0]           3648              Netherlands           0
# 59372    (-0.001, 20.0]           3670                      Tlc           0
# 59373  (20.0, 350000.0]           3761                    Rudep        1137
# 59374    (-0.001, 20.0]           3668                    Rwssp           0
# 59375  (20.0, 350000.0]           3215   Government Of Tanzania          54
# 59376    (-0.001, 20.0]           3765                    OTHER        1581
# 59377    (-0.001, 20.0]           3662   Government Of Tanzania           0
# 59378  (20.0, 350000.0]           3080                       Rc        2101
# 59379    (-0.001, 20.0]           3194                    OTHER           0
# 59380  (20.0, 350000.0]           3073                    Roman        1439
# 59381    (-0.001, 20.0]           3075      Mkinga Distric Coun           0
# 59382    (-0.001, 20.0]           3946                Ces(gmbh)        1383
# 59383    (-0.001, 20.0]           3750               World Bank          11
# 59384    (-0.001, 20.0]           3191                  Concern           0
# 59385  (20.0, 350000.0]           3673                    Jaica        1327
# 59386    (-0.001, 20.0]           3234                      Adb        1786
# 59387  (20.0, 350000.0]           3802                    OTHER          25
# 59388    (-0.001, 20.0]           3760                    OTHER        1414
# 59389    (-0.001, 20.0]           3218                       Co         783
# 59390    (-0.001, 20.0]           3216                    Rudep        1715
# 59391    (-0.001, 20.0]           3946   Government Of Tanzania         540
# 59392    (-0.001, 20.0]           3105   Government Of Tanzania           0
# 59393    (-0.001, 20.0]           3666                  Private           0
# 59394  (20.0, 350000.0]           3068               World Bank         351
# 59395    (-0.001, 20.0]           3854          Germany Republi        1210
# 59396  (20.0, 350000.0]           3127                    OTHER        1212
# 59397    (-0.001, 20.0]           3101                    OTHER           0
# 59398    (-0.001, 20.0]           3067                    OTHER           0
# 59399    (-0.001, 20.0]           3082               World Bank         191
#
#                   installer  longitude      latitude  \
# 0                     Roman  34.938093 -9.856322e+00
# 1                   GRUMETI  34.698766 -2.147466e+00
# 2              World vision  37.460664 -3.821329e+00
# 3                    UNICEF  38.486161 -1.115530e+01
# 4                   Artisan  31.130847 -1.825359e+00
# 5                       DWE  39.172796 -4.765587e+00
# 6                      DWSP  33.362410 -3.766365e+00
# 7                       DWE  32.620617 -4.226198e+00
# 8                 Water Aid  32.711100 -5.146712e+00
# 9                   Artisan  30.626991 -1.257051e+00
# 10                  Private  39.209518 -7.034139e+00
# 11                   DANIDA  35.770258 -1.057417e+01
# 12             World vision  33.798106 -3.290194e+00
# 13     Lawatefuka water sup  37.092574 -3.181783e+00
# 14                   WEDECO  34.364073 -3.629333e+00
# 15                      DWE  31.444121 -8.274962e+00
# 16                      DWE  34.642439 -9.106185e+00
# 17                      DWE  34.569266 -9.085515e+00
# 18                      DWE  32.920154 -1.947868e+00
# 19                    Danid  34.508967 -9.894412e+00
# 20                      TWE  34.473430 -9.594990e+00
# 21                      DWE   0.000000 -2.000000e-08
# 22                      DWE  34.586901 -8.980014e+00
# 23                      ISF  37.940029 -4.125595e+00
# 24                      DWE  29.747066 -4.495568e+00
# 25                      DWE  37.422751 -3.317536e+00
# 26              Kilolo Star  39.370777 -9.942532e+00
# 27                      DWE  31.104257 -1.735361e+00
# 28         District council  37.611126 -3.263526e+00
# 29     Lawatefuka water sup  37.061688 -3.191989e+00
# ...                     ...        ...           ...
# 59370                   NaN  30.058731 -4.902633e+00
# 59371                   DWE  33.586406 -3.040369e+00
# 59372                   TLC  32.058548 -5.052101e+00
# 59373                Distri  32.125024 -6.784358e+00
# 59374                   DWE   0.000000 -2.000000e-08
# 59375                   DWE  39.046942 -5.061494e+00
# 59376                   NaN  34.821039 -5.076258e+00
# 59377            Government  33.437012 -4.423594e+00
# 59378                  ACRA  34.620387 -9.358405e+00
# 59379                    DO  31.613284 -1.820226e+00
# 59380                 Roman  34.942101 -9.849198e+00
# 59381                   DWE  38.835001 -4.880204e+00
# 59382                   DWE  37.454759 -3.323599e+00
# 59383            World bank  39.626009 -1.005750e+01
# 59384               CONCERN  30.667805 -2.483710e+00
# 59385              JAICA CO  33.951681 -2.021854e+00
# 59386                   DWE  31.738789 -8.532013e+00
# 59387                     0  39.176480 -6.957098e+00
# 59388                   DWE  30.692400 -3.593827e+00
# 59389                   DWE  30.646486 -7.365418e+00
# 59390                   DWE  31.370848 -8.258160e+00
# 59391            Government  38.044070 -4.272218e+00
# 59392            Government  33.009440 -8.520888e+00
# 59393               Private  33.866852 -4.287410e+00
# 59394              ML appro  37.634053 -6.124830e+00
# 59395                   CES  37.169807 -3.253847e+00
# 59396                  Cefa  35.249991 -9.070629e+00
# 59397                   NaN  34.017087 -8.750434e+00
# 59398                  Musa  35.861315 -6.378573e+00
# 59399                 World  38.104048 -6.747464e+00
#
#                         wpt_name  num_private                    basin  \
# 0                           none            0               Lake Nyasa
# 1                       Zahanati            0            Lake Victoria
# 2                    Kwa Mahundi            0                  Pangani
# 3           Zahanati Ya Nanyumbu            0  Ruvuma / Southern Coast
# 4                        Shuleni            0            Lake Victoria
# 5                         Tajiri            0                  Pangani
# 6                     Kwa Ngomho            0                 Internal
# 7                   Tushirikiane            0          Lake Tanganyika
# 8              Kwa Ramadhan Musa            0          Lake Tanganyika
# 9                        Kwapeto            0            Lake Victoria
# 10                 Mzee Hokororo            0              Wami / Ruvu
# 11              Kwa Alid Nchimbi            0               Lake Nyasa
# 12                         Pamba            0                 Internal
# 13          Kwa John Izack Mmari            0                  Pangani
# 14                     Mwabasabi            0                 Internal
# 15        Kwa Juvenal Ching'Ombe            0          Lake Tanganyika
# 16               Kwa John Mtenzi            0                   Rufiji
# 17               Kwa Rose Chaula            0                   Rufiji
# 18                        Ngomee            0            Lake Victoria
# 19                          none            0               Lake Nyasa
# 20                          none            0               Lake Nyasa
# 21                      Muungano            0            Lake Victoria
# 22                       Shuleni            0                   Rufiji
# 23                       Kinonga            0                  Pangani
# 24                       Kamsasa            0          Lake Tanganyika
# 25                     Kwa Tukai            0                  Pangani
# 26         Ruhoma Primary School            0  Ruvuma / Southern Coast
# 27                    Kwawilliam            0            Lake Victoria
# 28                  Kwa Kibakaya            0                  Pangani
# 29             Kwa Willium Kinda            0                  Pangani
# ...                          ...          ...                      ...
# 59370             Village Office            0          Lake Tanganyika
# 59371                   Ushirika            0            Lake Victoria
# 59372           Kwa Mzee Kamanya            0          Lake Tanganyika
# 59373                Kwa Kadiega            0               Lake Rukwa
# 59374                 Nguvu Kazi            0            Lake Victoria
# 59375                  Sekondari            0                  Pangani
# 59376                    Nasingo            0                 Internal
# 59377                       Fpct            0                 Internal
# 59378             Michael Msigwa            0                   Rufiji
# 59379            Coffee Plantati            0            Lake Victoria
# 59380                       none            0               Lake Nyasa
# 59381                 Mijohoroni            0                  Pangani
# 59382             Kwa Luka Msaki            0                  Pangani
# 59383                    Shuleni            0  Ruvuma / Southern Coast
# 59384                   Chamkube            0            Lake Victoria
# 59385                Kwa Marunda            0            Lake Victoria
# 59386  Shule Ya Sekondari Katazi            0               Lake Rukwa
# 59387                 Kwa Maliba            0              Wami / Ruvu
# 59388         Kwa Philipo Kibeba            0          Lake Tanganyika
# 59389                  Sekondari            0          Lake Tanganyika
# 59390            Kwa Mzee Atanas            0          Lake Tanganyika
# 59391                        Kwa            0                  Pangani
# 59392             Benard Charles            0               Lake Rukwa
# 59393                  Kwa Peter            0                 Internal
# 59394                 Chimeredya            0              Wami / Ruvu
# 59395        Area Three Namba 27            0                  Pangani
# 59396          Kwa Yahona Kuvala            0                   Rufiji
# 59397                    Mashine            0                   Rufiji
# 59398                     Mshoro            0                   Rufiji
# 59399            Kwa Mzee Lugawa            0              Wami / Ruvu
#
#                ...          payment_type water_quality  quality_group  \
# 0              ...              annually          soft           good
# 1              ...             never pay          soft           good
# 2              ...            per bucket          soft           good
# 3              ...             never pay          soft           good
# 4              ...             never pay          soft           good
# 5              ...            per bucket         salty          salty
# 6              ...             never pay          soft           good
# 7              ...               unknown         milky          milky
# 8              ...             never pay         salty          salty
# 9              ...             never pay          soft           good
# 10             ...             never pay         salty          salty
# 11             ...            on failure          soft           good
# 12             ...                 other          soft           good
# 13             ...               monthly          soft           good
# 14             ...             never pay          soft           good
# 15             ...             never pay          soft           good
# 16             ...               monthly          soft           good
# 17             ...            on failure          soft           good
# 18             ...             never pay         milky          milky
# 19             ...              annually          soft           good
# 20             ...               monthly          soft           good
# 21             ...               unknown       unknown        unknown
# 22             ...             never pay          soft           good
# 23             ...               monthly          soft           good
# 24             ...               unknown          soft           good
# 25             ...               unknown          soft           good
# 26             ...               monthly          soft           good
# 27             ...             never pay          soft           good
# 28             ...               monthly          soft           good
# 29             ...               monthly          soft           good
# ...            ...                   ...           ...            ...
# 59370          ...               monthly       unknown        unknown
# 59371          ...             never pay          soft           good
# 59372          ...            per bucket         salty          salty
# 59373          ...              annually          soft           good
# 59374          ...                 other          soft           good
# 59375          ...               monthly          soft           good
# 59376          ...               unknown       unknown        unknown
# 59377          ...             never pay          soft           good
# 59378          ...               monthly          soft           good
# 59379          ...             never pay          soft           good
# 59380          ...              annually          soft           good
# 59381          ...             never pay          soft           good
# 59382          ...            per bucket          soft           good
# 59383          ...               unknown          soft           good
# 59384          ...             never pay          soft           good
# 59385          ...               monthly         salty          salty
# 59386          ...             never pay          soft           good
# 59387          ...            per bucket          soft           good
# 59388          ...               unknown          soft           good
# 59389          ...             never pay          soft           good
# 59390          ...             never pay          soft           good
# 59391          ...             never pay          soft           good
# 59392          ...             never pay          soft           good
# 59393          ...            per bucket          soft           good
# 59394          ...               monthly          soft           good
# 59395          ...            per bucket          soft           good
# 59396          ...              annually          soft           good
# 59397          ...               monthly      fluoride       fluoride
# 59398          ...             never pay          soft           good
# 59399          ...            on failure         salty          salty
#
#            quantity quantity_group                source  \
# 0            enough         enough                spring
# 1      insufficient   insufficient  rainwater harvesting
# 2            enough         enough                   dam
# 3               dry            dry           machine dbh
# 4          seasonal       seasonal  rainwater harvesting
# 5            enough         enough                 other
# 6            enough         enough           machine dbh
# 7            enough         enough          shallow well
# 8          seasonal       seasonal           machine dbh
# 9            enough         enough          shallow well
# 10           enough         enough           machine dbh
# 11     insufficient   insufficient          shallow well
# 12           enough         enough          shallow well
# 13           enough         enough                spring
# 14           enough         enough          shallow well
# 15           enough         enough           machine dbh
# 16              dry            dry                 river
# 17              dry            dry                 river
# 18     insufficient   insufficient                spring
# 19           enough         enough                spring
# 20           enough         enough                spring
# 21          unknown        unknown          shallow well
# 22           enough         enough                 river
# 23           enough         enough                 river
# 24           enough         enough                spring
# 25           enough         enough                spring
# 26           enough         enough           machine dbh
# 27           enough         enough          shallow well
# 28     insufficient   insufficient                spring
# 29           enough         enough                spring
# ...             ...            ...                   ...
# 59370       unknown        unknown               unknown
# 59371        enough         enough          shallow well
# 59372  insufficient   insufficient          shallow well
# 59373        enough         enough           machine dbh
# 59374        enough         enough          shallow well
# 59375        enough         enough                 river
# 59376           dry            dry          shallow well
# 59377  insufficient   insufficient                   dam
# 59378        enough         enough                spring
# 59379        enough         enough                spring
# 59380           dry            dry                spring
# 59381  insufficient   insufficient                spring
# 59382        enough         enough                spring
# 59383        enough         enough  rainwater harvesting
# 59384  insufficient   insufficient                spring
# 59385        enough         enough           machine dbh
# 59386        enough         enough           machine dbh
# 59387        enough         enough           machine dbh
# 59388  insufficient   insufficient                spring
# 59389        enough         enough           machine dbh
# 59390  insufficient   insufficient           machine dbh
# 59391        enough         enough                 river
# 59392        enough         enough                spring
# 59393  insufficient   insufficient                   dam
# 59394        enough         enough           machine dbh
# 59395        enough         enough                spring
# 59396        enough         enough                 river
# 59397        enough         enough           machine dbh
# 59398  insufficient   insufficient          shallow well
# 59399        enough         enough          shallow well
#
#                 source_type source_class              waterpoint_type  \
# 0                    spring  groundwater           communal standpipe
# 1      rainwater harvesting      surface           communal standpipe
# 2                       dam      surface  communal standpipe multiple
# 3                  borehole  groundwater  communal standpipe multiple
# 4      rainwater harvesting      surface           communal standpipe
# 5                     other      unknown  communal standpipe multiple
# 6                  borehole  groundwater                    hand pump
# 7              shallow well  groundwater                    hand pump
# 8                  borehole  groundwater                    hand pump
# 9              shallow well  groundwater                    hand pump
# 10                 borehole  groundwater                        other
# 11             shallow well  groundwater                    hand pump
# 12             shallow well  groundwater                    hand pump
# 13                   spring  groundwater           communal standpipe
# 14             shallow well  groundwater                    hand pump
# 15                 borehole  groundwater                    hand pump
# 16               river/lake      surface           communal standpipe
# 17               river/lake      surface           communal standpipe
# 18                   spring  groundwater                        other
# 19                   spring  groundwater           communal standpipe
# 20                   spring  groundwater           communal standpipe
# 21             shallow well  groundwater                    hand pump
# 22               river/lake      surface           communal standpipe
# 23               river/lake      surface           communal standpipe
# 24                   spring  groundwater              improved spring
# 25                   spring  groundwater           communal standpipe
# 26                 borehole  groundwater                    hand pump
# 27             shallow well  groundwater                    hand pump
# 28                   spring  groundwater           communal standpipe
# 29                   spring  groundwater           communal standpipe
# ...                     ...          ...                          ...
# 59370                 other      unknown                        other
# 59371          shallow well  groundwater                    hand pump
# 59372          shallow well  groundwater                        other
# 59373              borehole  groundwater                    hand pump
# 59374          shallow well  groundwater                    hand pump
# 59375            river/lake      surface           communal standpipe
# 59376          shallow well  groundwater                        other
# 59377                   dam      surface  communal standpipe multiple
# 59378                spring  groundwater           communal standpipe
# 59379                spring  groundwater           communal standpipe
# 59380                spring  groundwater           communal standpipe
# 59381                spring  groundwater           communal standpipe
# 59382                spring  groundwater           communal standpipe
# 59383  rainwater harvesting      surface                    hand pump
# 59384                spring  groundwater           communal standpipe
# 59385              borehole  groundwater                    hand pump
# 59386              borehole  groundwater                    hand pump
# 59387              borehole  groundwater           communal standpipe
# 59388                spring  groundwater              improved spring
# 59389              borehole  groundwater                    hand pump
# 59390              borehole  groundwater                    hand pump
# 59391            river/lake      surface           communal standpipe
# 59392                spring  groundwater           communal standpipe
# 59393                   dam      surface                        other
# 59394              borehole  groundwater           communal standpipe
# 59395                spring  groundwater           communal standpipe
# 59396            river/lake      surface           communal standpipe
# 59397              borehole  groundwater                    hand pump
# 59398          shallow well  groundwater                    hand pump
# 59399          shallow well  groundwater                    hand pump
#
#       waterpoint_type_group
# 0        communal standpipe
# 1        communal standpipe
# 2        communal standpipe
# 3        communal standpipe
# 4        communal standpipe
# 5        communal standpipe
# 6                 hand pump
# 7                 hand pump
# 8                 hand pump
# 9                 hand pump
# 10                    other
# 11                hand pump
# 12                hand pump
# 13       communal standpipe
# 14                hand pump
# 15                hand pump
# 16       communal standpipe
# 17       communal standpipe
# 18                    other
# 19       communal standpipe
# 20       communal standpipe
# 21                hand pump
# 22       communal standpipe
# 23       communal standpipe
# 24          improved spring
# 25       communal standpipe
# 26                hand pump
# 27                hand pump
# 28       communal standpipe
# 29       communal standpipe
# ...                     ...
# 59370                 other
# 59371             hand pump
# 59372                 other
# 59373             hand pump
# 59374             hand pump
# 59375    communal standpipe
# 59376                 other
# 59377    communal standpipe
# 59378    communal standpipe
# 59379    communal standpipe
# 59380    communal standpipe
# 59381    communal standpipe
# 59382    communal standpipe
# 59383             hand pump
# 59384    communal standpipe
# 59385             hand pump
# 59386             hand pump
# 59387    communal standpipe
# 59388       improved spring
# 59389             hand pump
# 59390             hand pump
# 59391    communal standpipe
# 59392    communal standpipe
# 59393                 other
# 59394    communal standpipe
# 59395    communal standpipe
# 59396    communal standpipe
# 59397             hand pump
# 59398             hand pump
# 59399             hand pump
#
# [59400 rows x 39 columns]

# %%
train_X.columns
#str (train_X['date_recorded'].dtype) # 'datetime64[ns]'
# Out:
# Index(['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height',
#        'installer', 'longitude', 'latitude', 'wpt_name', 'num_private',
#        'basin', 'subvillage', 'region', 'region_code', 'district_code', 'lga',
#        'ward', 'population', 'public_meeting', 'recorded_by',
#        'scheme_management', 'scheme_name', 'permit', 'construction_year',
#        'extraction_type', 'extraction_type_group', 'extraction_type_class',
#        'management', 'management_group', 'payment', 'payment_type',
#        'water_quality', 'quality_group', 'quantity', 'quantity_group',
#        'source', 'source_type', 'source_class', 'waterpoint_type',
#        'waterpoint_type_group'],
#       dtype='object')

# %%
#train_X
