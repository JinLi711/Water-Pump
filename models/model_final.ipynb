# %% [markdown]
# # Train on All Data

# %% [markdown]
# ## Load Items

# %%
import sys
sys.path.insert(0, '../preprocess')

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 100)

import importlib
import output_visualization as ov
importlib.reload(ov)
import feature_engineering as fe
import model_helper_funcs as mhf
importlib.reload(fe)

import xgboost as xgb

# %%
train_X, valid_X, train_y, valid_y = fe.get_data(
    '../data/train.csv', 
    '../data/train_labels.csv',
    valid_size=0.0 # train on all the data
)
# Out:
# memory used before preprocess:  19.00808
#
# date time size before: 3.9798799999999996
# date time size after:  0.47528
#
# converting funder                         size:  3.86	->	 0.33
# converting installer                      size:  3.64	->	 0.34
# converting basin                          size:  4.03	->	 0.06
# converting subvillage                     size:  3.85	->	 2.03
# converting region                         size:  3.78	->	 0.06
# converting lga                            size:  3.83	->	 0.07
# converting ward                           size:  3.83	->	 0.34
# converting public_meeting                 size:  2.1	->	 0.06
# converting recorded_by                    size:  4.75	->	 0.06
# converting scheme_management              size:  3.55	->	 0.06
# converting scheme_name                    size:  3.15	->	 0.4
# converting permit                         size:  2.06	->	 0.06
# converting extraction_type                size:  3.84	->	 0.06
# converting extraction_type_group          size:  3.85	->	 0.06
# converting extraction_type_class          size:  3.84	->	 0.06
# converting management                     size:  3.64	->	 0.06
# converting management_group               size:  3.97	->	 0.06
# converting payment                        size:  4.02	->	 0.06
# converting payment_type                   size:  3.89	->	 0.06
# converting water_quality                  size:  3.64	->	 0.06
# converting quality_group                  size:  3.64	->	 0.06
# converting quantity                       size:  3.82	->	 0.06
# converting quantity_group                 size:  3.82	->	 0.06
# converting source                         size:  3.92	->	 0.06
# converting source_type                    size:  3.94	->	 0.06
# converting source_class                   size:  3.98	->	 0.06
# converting waterpoint_type                size:  4.27	->	 0.06
# converting waterpoint_type_group          size:  4.21	->	 0.06
#
# downcasting integers for: ['id', 'gps_height', 'num_private', 'region_code', 'district_code', 'population', 'construction_year']
#
# reduced memory usage for:   id                  from     0.48 to     0.24
# reduced memory usage for:   gps_height          from     0.48 to     0.12
# reduced memory usage for:   num_private         from     0.48 to     0.12
# reduced memory usage for:   region_code         from     0.48 to     0.06
# reduced memory usage for:   district_code       from     0.48 to     0.06
# reduced memory usage for:   population          from     0.48 to     0.12
# reduced memory usage for:   construction_year   from     0.48 to     0.12
#
# available RAM: svmem(total=8589934592, available=1466417152, percent=82.9, used=5756489728, free=22405120, active=1972387840, inactive=1444012032, wired=2340089856)
# available RAM: svmem(total=8589934592, available=1466523648, percent=82.9, used=5756489728, free=22511616, active=1972387840, inactive=1444012032, wired=2340089856)
#
# memory used after preprocess:  6.3896

# %%
trans = fe.DataCleaning()
transformed_train_X = trans.fit_transform(train_X)
train_y = transformed_train_X['status_group']
transformed_train_X.drop(['status_group'], axis=1, inplace=True)
col_names = transformed_train_X.columns

# %%
transformed_train_X.head()
# transformed_train_X.shape
# Out:
#        amount_tsh  date_recorded                          funder  gps_height  \
# 2980     0.000000           3648  Rural Water Supply And Sanitat           0
# 5246     0.000000           3673                           OTHER           0
# 22659    2.397895           3787                           OTHER        1675
# 39888    0.000000           3225                            Kkkt           0
# 13361    3.931826           3770                        Wateraid        1109
#
#       installer  longitude  latitude     region district_code  population  \
# 2980        DWE  31.985658 -3.596360  Shinyanga             5           0
# 5246      OTHER  32.832815 -4.944937     Tabora             6           0
# 22659       DWE  35.488289 -4.242048    Manyara             1         148
# 39888      KKKT  33.140828 -9.059386      Mbeya             6           0
# 13361      SEMA  34.217077 -4.430529    Singida             1         235
#
#       public_meeting scheme_management permit  construction_year  \
# 2980            True               WUG   True               40.0
# 5246            True               VWC   True               40.0
# 22659           True       Water Board   True               48.0
# 39888          False               VWC  False               40.0
# 13361           True               WUA   True               51.0
#
#       extraction_type_class   management payment_type quality_group  \
# 2980                  other          wug      unknown          good
# 5246               handpump          vwc    never pay         milky
# 22659               gravity  water board   per bucket          good
# 39888              handpump          vwc    never pay          good
# 13361             motorpump          wua   per bucket          good
#
#       quantity_group        source waterpoint_type_group
# 2980             dry  shallow well                 other
# 5246    insufficient  shallow well             hand pump
# 22659   insufficient        spring    communal standpipe
# 39888       seasonal  shallow well             hand pump
# 13361         enough   machine dbh    communal standpipe

# %%
train_X_numeric, pipeline_ord = fe.transform_df(transformed_train_X, cat_encode_type="numeric")
train_X_1hot, pipeline_1hot = fe.transform_df(transformed_train_X, cat_encode_type="one hot")
train_X_numeric = pd.DataFrame(train_X_numeric, columns=col_names)
train_X_1hot.shape
# Out:
# (59400, 292)

# %%
train_X_numeric.shape
# Out:
# (59400, 21)

# %%
y_encoder_num, train_y_num = fe.encode_labels(train_y, convert_type="numeric")

# %% [markdown]
# ## XGB

# %%
# %%time
# Best Model

xgc = xgb.XGBClassifier(
    n_estimators=500,
    max_depth=8,
    base_score=0.5,
    objective='multi:softprob', 
    random_state=42
)
xgc.fit(train_X_numeric, train_y_num)
print (xgc)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=8, min_child_weight=1, missing=None, n_estimators=500,
#        n_jobs=1, nthread=None, objective='multi:softprob', random_state=42,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)
# CPU times: user 4min 56s, sys: 2.57 s, total: 4min 59s
# Wall time: 5min 15s

# %% [markdown]
# ## Final Test Data (Unlabeled)

# %%
# test = pd.read_csv('../data/test.csv') 
# test['status_group'] = np.nan
test = fe.get_test('../data/test.csv', )
# Out:
# memory used before preprocess:  4.752079999999999
#
# date time size before: 0.99503
# date time size after:  0.11888
#
# converting funder                         size:  0.96	->	 0.14
# converting installer                      size:  0.91	->	 0.14
# converting basin                          size:  1.01	->	 0.02
# converting subvillage                     size:  0.96	->	 0.91
# converting region                         size:  0.95	->	 0.02
# converting lga                            size:  0.96	->	 0.03
# converting ward                           size:  0.96	->	 0.24
# converting public_meeting                 size:  0.53	->	 0.02
# converting recorded_by                    size:  1.19	->	 0.02
# converting scheme_management              size:  0.89	->	 0.02
# converting scheme_name                    size:  0.78	->	 0.24
# converting permit                         size:  0.51	->	 0.02
# converting extraction_type                size:  0.96	->	 0.02
# converting extraction_type_group          size:  0.96	->	 0.02
# converting extraction_type_class          size:  0.96	->	 0.02
# converting management                     size:  0.91	->	 0.02
# converting management_group               size:  0.99	->	 0.02
# converting payment                        size:  1.0	->	 0.02
# converting payment_type                   size:  0.97	->	 0.02
# converting water_quality                  size:  0.91	->	 0.02
# converting quality_group                  size:  0.91	->	 0.02
# converting quantity                       size:  0.96	->	 0.02
# converting quantity_group                 size:  0.96	->	 0.02
# converting source                         size:  0.98	->	 0.02
# converting source_type                    size:  0.98	->	 0.02
# converting source_class                   size:  1.0	->	 0.02
# converting waterpoint_type                size:  1.07	->	 0.02
# converting waterpoint_type_group          size:  1.05	->	 0.02
#
# downcasting integers for: ['id', 'gps_height', 'num_private', 'region_code', 'district_code', 'population', 'construction_year']
#
# reduced memory usage for:   id                  from     0.12 to     0.06
# reduced memory usage for:   gps_height          from     0.12 to     0.03
# reduced memory usage for:   num_private         from     0.12 to     0.03
# reduced memory usage for:   region_code         from     0.12 to     0.01
# reduced memory usage for:   district_code       from     0.12 to     0.01
# reduced memory usage for:   population          from     0.12 to     0.03
# reduced memory usage for:   construction_year   from     0.12 to     0.03
#
# available RAM: svmem(total=8589934592, available=1695535104, percent=80.3, used=5751705600, free=64118784, active=1903390720, inactive=1631416320, wired=2216898560)
# available RAM: svmem(total=8589934592, available=1695100928, percent=80.3, used=5752967168, free=63750144, active=1903984640, inactive=1631350784, wired=2217631744)
#
# memory used after preprocess:  1.993294

# %%
test.head()
# Out:
#       id  amount_tsh date_recorded                  funder  gps_height  \
# 0  50785         0.0    2013-02-04                    Dmdd        1996
# 1  51630         0.0    2013-02-04  Government Of Tanzania        1569
# 2  17168         0.0    2013-02-01                     NaN        1567
# 3  45559         0.0    2013-01-22              Finn Water         267
# 4  49871       500.0    2013-03-27                  Bruder        1260
#
#     installer  longitude   latitude                 wpt_name  num_private  \
# 0        DMDD  35.290799  -4.059696  Dinamu Secondary School            0
# 1         DWE  36.656709  -3.309214                  Kimnyak            0
# 2         NaN  34.767863  -5.004344           Puma Secondary            0
# 3  FINN WATER  38.058046  -9.418672           Kwa Mzee Pange            0
# 4      BRUDER  35.006123 -10.950412          Kwa Mzee Turuka            0
#
#                      basin  subvillage   region region_code district_code  \
# 0                 Internal      Magoma  Manyara          21             3
# 1                  Pangani     Kimnyak   Arusha           2             2
# 2                 Internal       Msatu  Singida          13             2
# 3  Ruvuma / Southern Coast  Kipindimbi    Lindi          80            43
# 4  Ruvuma / Southern Coast     Losonga   Ruvuma          10             3
#
#              lga          ward  population public_meeting  \
# 0          Mbulu        Bashay         321           True
# 1   Arusha Rural      Kimnyaki         300           True
# 2  Singida Rural          Puma         500           True
# 3         Liwale       Mkutano         250            NaN
# 4         Mbinga  Mbinga Urban          60            NaN
#
#                recorded_by scheme_management     scheme_name permit  \
# 0  GeoData Consultants Ltd        Parastatal             NaN   True
# 1  GeoData Consultants Ltd               VWC  TPRI pipe line   True
# 2  GeoData Consultants Ltd               VWC               P    NaN
# 3  GeoData Consultants Ltd               VWC             NaN   True
# 4  GeoData Consultants Ltd       Water Board          BRUDER   True
#
#    construction_year extraction_type extraction_type_group  \
# 0               2012           other                 other
# 1               2000         gravity               gravity
# 2               2010           other                 other
# 3               1987           other                 other
# 4               2000         gravity               gravity
#
#   extraction_type_class   management management_group      payment  \
# 0                 other   parastatal       parastatal    never pay
# 1               gravity          vwc       user-group    never pay
# 2                 other          vwc       user-group    never pay
# 3                 other          vwc       user-group      unknown
# 4               gravity  water board       user-group  pay monthly
#
#   payment_type water_quality quality_group      quantity quantity_group  \
# 0    never pay          soft          good      seasonal       seasonal
# 1    never pay          soft          good  insufficient   insufficient
# 2    never pay          soft          good  insufficient   insufficient
# 3      unknown          soft          good           dry            dry
# 4      monthly          soft          good        enough         enough
#
#                  source           source_type source_class  \
# 0  rainwater harvesting  rainwater harvesting      surface
# 1                spring                spring  groundwater
# 2  rainwater harvesting  rainwater harvesting      surface
# 3          shallow well          shallow well  groundwater
# 4                spring                spring  groundwater
#
#       waterpoint_type waterpoint_type_group  status_group
# 0               other                 other           NaN
# 1  communal standpipe    communal standpipe           NaN
# 2               other                 other           NaN
# 3               other                 other           NaN
# 4  communal standpipe    communal standpipe           NaN

# %%
transformed_test = trans.transform(test)
transformed_test.drop(['status_group'], axis=1, inplace=True)
transformed_test.head()
# Out:
#    amount_tsh  date_recorded                  funder  gps_height installer  \
# 0    0.000000           4333                   OTHER        1996     OTHER
# 1    0.000000           4333  Government Of Tanzania        1569       DWE
# 2    0.000000           4330                   OTHER        1567     OTHER
# 3    0.000000           4320                   OTHER         267     OTHER
# 4    6.216606           4384                   OTHER        1260     OTHER
#
#    longitude   latitude   region district_code  population public_meeting  \
# 0  35.290799  -4.059696  Manyara             3         321           True
# 1  36.656709  -3.309214   Arusha             2         300           True
# 2  34.767863  -5.004344  Singida             2         500           True
# 3  38.058046  -9.418672    Lindi            43         250           True
# 4  35.006123 -10.950412   Ruvuma             3          60           True
#
#   scheme_management permit  construction_year extraction_type_class  \
# 0        Parastatal   True               52.0                 other
# 1               VWC   True               40.0               gravity
# 2               VWC   True               50.0                 other
# 3               VWC   True               27.0                 other
# 4       Water Board   True               40.0               gravity
#
#     management payment_type quality_group quantity_group  \
# 0   parastatal    never pay          good       seasonal
# 1          vwc    never pay          good   insufficient
# 2          vwc    never pay          good   insufficient
# 3          vwc      unknown          good            dry
# 4  water board      monthly          good         enough
#
#                  source waterpoint_type_group
# 0  rainwater harvesting                 other
# 1                spring    communal standpipe
# 2  rainwater harvesting                 other
# 3          shallow well                 other
# 4                spring    communal standpipe

# %%
test_numeric = pipeline_ord.transform (transformed_test)
test_1hot = pipeline_1hot.transform(transformed_test)
test_numeric = pipeline_ord.transform(transformed_test)
test_numeric = pd.DataFrame(data=test_numeric, columns=col_names, )
test_1hot.shape
# Out:
# (14850, 292)

# %% [markdown]
# ## Test Prediction

# %%
y_pred = xgc.predict(test_numeric)

# %% [markdown]
# ## Submission Format

# %%
submission_ex = pd.read_csv('../data/SubmissionFormat.csv')
submission_ex.head()
# Out:
#       id     status_group
# 0  50785  predicted label
# 1  51630  predicted label
# 2  17168  predicted label
# 3  45559  predicted label
# 4  49871  predicted label

# %% [markdown]
# ## Final Results

# %%
cat_pred = y_encoder_num.inverse_transform (y_pred)
final_results = pd.DataFrame({
    'id': test['id'].values,
    'status_group': cat_pred
})

# %%
# final_results = pd.to_numeric(final_results)
# final_results = final_results.astype('category')

# %%
final_results.head()
# Out:
#       id    status_group
# 0  50785      functional
# 1  51630      functional
# 2  17168      functional
# 3  45559  non functional
# 4  49871      functional

# %%
final_results.to_csv('../data/test_predictions.csv', index=False)
